# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.49-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.4.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.19.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.49-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 12.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.49 ultralytics-thop-2.0.13

# %%
# !pip install deep_sort_realtime
# Out:
# Collecting deep_sort_realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from deep_sort_realtime) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from deep_sort_realtime) (1.14.1)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from deep_sort_realtime) (4.10.0.84)
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 27.5 MB/s eta 0:00:00
# Installing collected packages: deep_sort_realtime
# Successfully installed deep_sort_realtime-1.3.2

# %%
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from opencv-python-headless) (1.26.4)

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2

# Initialize YOLO model
model_path = '/kaggle/input/detection-model-best/best.pt'  # Replace with your model path
model = YOLO(model_path)

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video path
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'  # Replace with your video path
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video settings
output_video_path = '/kaggle/working/processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Movement data structures
sheep_tracks = defaultdict(list)
prev_positions = {}  # Store previous positions for speed calculation
abnormal_ids = set()  # Track IDs with abnormal speed

# Speed thresholds (pixels/frame)
NORMAL_SPEED_MIN = 10.0
NORMAL_SPEED_MAX = 20.0

# Process video frames
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or unable to read frame.")
        break

    # Detect sheep using YOLO
    results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
    detections = []
    for result in results:
        for box in result.boxes:
            try:
                x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                if confidence > 0.5 and class_id == 0:  # Sheep class
                    detections.append([[x1, y1, x2, y2], confidence])
            except Exception as e:
                print(f"Error processing box: {e}")
                continue

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        x, y, w, h = track.to_ltwh()
        center_x = int(x + w / 2)
        center_y = int(y + h / 2)

        # Track movement
        sheep_tracks[track_id].append((center_x, center_y))

        # Calculate speed
        if track_id in prev_positions:
            prev_x, prev_y = prev_positions[track_id]
            speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

            # Flag abnormal speeds
            if speed < NORMAL_SPEED_MIN or speed > NORMAL_SPEED_MAX:
                abnormal_ids.add(track_id)
                cv2.putText(frame, f"ID {track_id} (Abnormal Speed)", (int(x), int(y) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
        prev_positions[track_id] = (center_x, center_y)

        # Draw bounding box and ID
        color = (0, 0, 255) if track_id in abnormal_ids else (0, 255, 0)
        cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
        cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Write frame to output video
    out.write(frame)
    frame_count += 1

# Release resources
cap.release()
out.release()

# Plot sheep movement
plt.figure(figsize=(12, 8))
for track_id, path in sheep_tracks.items():
    x_coords = [p[0] for p in path]
    y_coords = [p[1] for p in path]
    linestyle = '--' if track_id in abnormal_ids else '-'
    color = 'red' if track_id in abnormal_ids else 'green'
    plt.plot(x_coords, y_coords, linestyle=linestyle, color=color, label=f"ID {track_id}")

plt.xlabel("X-Coordinate (pixels)")
plt.ylabel("Y-Coordinate (pixels)")
plt.title("Sheep Movement Paths")
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis()  # Invert Y-axis for video frame coordinates

# Save movement graph
graph_path = '/kaggle/working/sheep_movement_graph.png'
plt.savefig(graph_path)
plt.close()

print("Processing complete.")
print(f"Processed video saved at: {output_video_path}")
print(f"Movement graph saved at: {graph_path}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# 0: 480x800 1 sheep, 1164.4ms
# Speed: 8.7ms preprocess, 1164.4ms inference, 13.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1008.6ms
# Speed: 8.1ms preprocess, 1008.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 956.6ms
# Speed: 4.0ms preprocess, 956.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 980.1ms
# Speed: 4.8ms preprocess, 980.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 938.7ms
# Speed: 5.6ms preprocess, 938.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 950.6ms
# Speed: 4.8ms preprocess, 950.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 952.7ms
# Speed: 4.7ms preprocess, 952.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 991.9ms
# Speed: 11.9ms preprocess, 991.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 972.1ms
# Speed: 19.7ms preprocess, 972.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.4ms
# Speed: 17.1ms preprocess, 974.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 985.4ms
# Speed: 14.5ms preprocess, 985.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 979.9ms
# Speed: 16.9ms preprocess, 979.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 979.7ms
# Speed: 23.4ms preprocess, 979.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 989.1ms
# Speed: 12.8ms preprocess, 989.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 983.3ms
# Speed: 13.0ms preprocess, 983.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 989.2ms
# Speed: 13.4ms preprocess, 989.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 990.2ms
# Speed: 5.9ms preprocess, 990.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 987.2ms
# Speed: 10.2ms preprocess, 987.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 969.4ms
# Speed: 18.5ms preprocess, 969.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 964.7ms
# Speed: 17.9ms preprocess, 964.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 988.2ms
# Speed: 19.1ms preprocess, 988.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 958.2ms
# Speed: 13.3ms preprocess, 958.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 976.9ms
# Speed: 17.5ms preprocess, 976.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 979.1ms
# Speed: 10.6ms preprocess, 979.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.4ms
# Speed: 29.8ms preprocess, 974.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 946.4ms
# Speed: 14.7ms preprocess, 946.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 966.7ms
# Speed: 17.9ms preprocess, 966.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.5ms
# Speed: 14.9ms preprocess, 974.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 977.1ms
# Speed: 24.7ms preprocess, 977.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1027.3ms
# Speed: 7.3ms preprocess, 1027.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 994.3ms
# Speed: 20.6ms preprocess, 994.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.7ms
# Speed: 9.5ms preprocess, 971.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 968.9ms
# Speed: 15.8ms preprocess, 968.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 982.9ms
# Speed: 18.8ms preprocess, 982.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 986.5ms
# Speed: 6.8ms preprocess, 986.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 972.1ms
# Speed: 9.3ms preprocess, 972.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 979.1ms
# Speed: 14.3ms preprocess, 979.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 964.5ms
# Speed: 22.4ms preprocess, 964.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 973.2ms
# Speed: 24.0ms preprocess, 973.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 997.5ms
# Speed: 22.4ms preprocess, 997.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.6ms
# Speed: 13.1ms preprocess, 959.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 976.8ms
# Speed: 16.0ms preprocess, 976.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1006.0ms
# Speed: 13.8ms preprocess, 1006.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1009.3ms
# Speed: 8.2ms preprocess, 1009.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 995.1ms
# Speed: 16.9ms preprocess, 995.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 970.1ms
# Speed: 7.9ms preprocess, 970.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.6ms
# Speed: 18.5ms preprocess, 975.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 961.3ms
# Speed: 16.3ms preprocess, 961.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 960.1ms
# Speed: 14.8ms preprocess, 960.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.1ms
# Speed: 12.9ms preprocess, 975.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 981.1ms
# Speed: 23.7ms preprocess, 981.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1012.1ms
# Speed: 26.8ms preprocess, 1012.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1004.2ms
# Speed: 9.2ms preprocess, 1004.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.2ms
# Speed: 12.6ms preprocess, 974.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.3ms
# Speed: 9.0ms preprocess, 971.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 981.8ms
# Speed: 12.3ms preprocess, 981.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 986.5ms
# Speed: 12.9ms preprocess, 986.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 991.1ms
# Speed: 21.8ms preprocess, 991.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1030.8ms
# Speed: 8.3ms preprocess, 1030.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1010.6ms
# Speed: 18.3ms preprocess, 1010.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1013.8ms
# Speed: 25.7ms preprocess, 1013.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.6ms
# Speed: 22.1ms preprocess, 959.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 978.4ms
# Speed: 10.0ms preprocess, 978.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 966.0ms
# Speed: 14.3ms preprocess, 966.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 987.6ms
# Speed: 10.6ms preprocess, 987.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 968.7ms
# Speed: 23.8ms preprocess, 968.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.7ms
# Speed: 24.8ms preprocess, 965.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 945.3ms
# Speed: 13.0ms preprocess, 945.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 969.4ms
# Speed: 6.6ms preprocess, 969.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1004.2ms
# Speed: 26.9ms preprocess, 1004.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 983.2ms
# Speed: 13.9ms preprocess, 983.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 991.7ms
# Speed: 11.4ms preprocess, 991.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 995.0ms
# Speed: 7.2ms preprocess, 995.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 980.9ms
# Speed: 10.2ms preprocess, 980.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 985.8ms
# Speed: 16.4ms preprocess, 985.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.1ms
# Speed: 13.5ms preprocess, 965.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 966.2ms
# Speed: 15.9ms preprocess, 966.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 978.7ms
# Speed: 14.0ms preprocess, 978.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1003.8ms
# Speed: 6.8ms preprocess, 1003.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 989.2ms
# Speed: 15.0ms preprocess, 989.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.9ms
# Speed: 10.2ms preprocess, 965.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 973.9ms
# Speed: 11.0ms preprocess, 973.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 984.8ms
# Speed: 20.7ms preprocess, 984.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.3ms
# Speed: 20.1ms preprocess, 974.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 972.0ms
# Speed: 8.0ms preprocess, 972.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 993.0ms
# Speed: 14.9ms preprocess, 993.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 987.6ms
# Speed: 6.7ms preprocess, 987.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1091.3ms
# Speed: 30.4ms preprocess, 1091.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 992.4ms
# Speed: 13.5ms preprocess, 992.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 938.2ms
# Speed: 25.8ms preprocess, 938.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 982.2ms
# Speed: 17.6ms preprocess, 982.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 949.9ms
# Speed: 22.5ms preprocess, 949.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.2ms
# Speed: 23.0ms preprocess, 965.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 966.7ms
# Speed: 9.9ms preprocess, 966.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.8ms
# Speed: 5.5ms preprocess, 959.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 943.9ms
# Speed: 12.6ms preprocess, 943.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.1ms
# Speed: 6.5ms preprocess, 974.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.8ms
# Speed: 7.5ms preprocess, 975.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 943.6ms
# Speed: 29.8ms preprocess, 943.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.5ms
# Speed: 10.0ms preprocess, 959.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 955.0ms
# Speed: 8.2ms preprocess, 955.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.2ms
# Speed: 9.5ms preprocess, 959.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 951.0ms
# Speed: 8.7ms preprocess, 951.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 991.5ms
# Speed: 6.3ms preprocess, 991.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 981.2ms
# Speed: 7.7ms preprocess, 981.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1001.3ms
# Speed: 16.2ms preprocess, 1001.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 956.8ms
# Speed: 17.8ms preprocess, 956.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 984.2ms
# Speed: 12.9ms preprocess, 984.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1056.4ms
# Speed: 18.6ms preprocess, 1056.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1027.0ms
# Speed: 23.0ms preprocess, 1027.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1032.2ms
# Speed: 14.4ms preprocess, 1032.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1017.3ms
# Speed: 25.9ms preprocess, 1017.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1031.5ms
# Speed: 20.1ms preprocess, 1031.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1036.0ms
# Speed: 11.7ms preprocess, 1036.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1054.1ms
# Speed: 11.3ms preprocess, 1054.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.3ms
# Speed: 25.8ms preprocess, 975.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1049.1ms
# Speed: 22.9ms preprocess, 1049.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 986.9ms
# Speed: 29.0ms preprocess, 986.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.8ms
# Speed: 16.4ms preprocess, 975.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 992.1ms
# Speed: 20.6ms preprocess, 992.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.6ms
# Speed: 17.7ms preprocess, 965.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.4ms
# Speed: 13.9ms preprocess, 975.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 988.4ms
# Speed: 12.5ms preprocess, 988.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 973.0ms
# Speed: 13.4ms preprocess, 973.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 973.1ms
# Speed: 14.0ms preprocess, 973.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 983.2ms
# Speed: 12.8ms preprocess, 983.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 977.9ms
# Speed: 9.1ms preprocess, 977.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 968.3ms
# Speed: 24.6ms preprocess, 968.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 975.5ms
# Speed: 13.4ms preprocess, 975.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 979.0ms
# Speed: 14.9ms preprocess, 979.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 978.9ms
# Speed: 13.2ms preprocess, 978.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 989.3ms
# Speed: 14.3ms preprocess, 989.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 985.8ms
# Speed: 5.7ms preprocess, 985.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 972.5ms
# Speed: 23.0ms preprocess, 972.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 958.1ms
# Speed: 24.3ms preprocess, 958.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.3ms
# Speed: 26.4ms preprocess, 971.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.4ms
# Speed: 6.7ms preprocess, 971.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 957.6ms
# Speed: 34.0ms preprocess, 957.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 969.9ms
# Speed: 9.9ms preprocess, 969.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 985.7ms
# Speed: 8.3ms preprocess, 985.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 960.9ms
# Speed: 23.4ms preprocess, 960.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 967.8ms
# Speed: 13.8ms preprocess, 967.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.8ms
# Speed: 17.8ms preprocess, 971.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 963.4ms
# Speed: 13.5ms preprocess, 963.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 958.7ms
# Speed: 17.9ms preprocess, 958.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1007.4ms
# Speed: 9.1ms preprocess, 1007.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 1006.6ms
# Speed: 22.3ms preprocess, 1006.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 944.2ms
# Speed: 12.2ms preprocess, 944.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 985.9ms
# Speed: 5.7ms preprocess, 985.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.1ms
# Speed: 25.8ms preprocess, 965.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 973.5ms
# Speed: 27.3ms preprocess, 973.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 966.7ms
# Speed: 8.9ms preprocess, 966.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 968.2ms
# Speed: 14.1ms preprocess, 968.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 976.8ms
# Speed: 14.4ms preprocess, 976.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 970.9ms
# Speed: 12.0ms preprocess, 970.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 967.9ms
# Speed: 9.8ms preprocess, 967.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 960.9ms
# Speed: 24.4ms preprocess, 960.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 954.2ms
# Speed: 20.1ms preprocess, 954.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.0ms
# Speed: 21.7ms preprocess, 959.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 962.4ms
# Speed: 6.6ms preprocess, 962.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 968.1ms
# Speed: 14.9ms preprocess, 968.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 971.2ms
# Speed: 17.2ms preprocess, 971.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 974.6ms
# Speed: 7.9ms preprocess, 974.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 981.3ms
# Speed: 6.3ms preprocess, 981.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 958.1ms
# Speed: 11.9ms preprocess, 958.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 955.8ms
# Speed: 10.7ms preprocess, 955.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 969.3ms
# Speed: 11.8ms preprocess, 969.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 959.8ms
# Speed: 20.5ms preprocess, 959.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 940.0ms
# Speed: 11.4ms preprocess, 940.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 946.5ms
# Speed: 6.5ms preprocess, 946.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 961.2ms
# Speed: 5.6ms preprocess, 961.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 946.7ms
# Speed: 8.1ms preprocess, 946.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 965.0ms
# Speed: 17.5ms preprocess, 965.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 946.2ms
# Speed: 6.1ms preprocess, 946.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 1032.8ms
# Speed: 6.8ms preprocess, 1032.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.2ms
# Speed: 27.1ms preprocess, 915.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 927.9ms
# Speed: 15.3ms preprocess, 927.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 942.9ms
# Speed: 18.9ms preprocess, 942.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 909.4ms
# Speed: 24.7ms preprocess, 909.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 1 sheep, 903.5ms
# Speed: 29.5ms preprocess, 903.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 927.1ms
# Speed: 6.9ms preprocess, 927.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.2ms
# Speed: 8.6ms preprocess, 921.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.2ms
# Speed: 7.5ms preprocess, 916.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 925.1ms
# Speed: 7.8ms preprocess, 925.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 928.5ms
# Speed: 17.9ms preprocess, 928.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.2ms
# Speed: 29.7ms preprocess, 919.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 941.2ms
# Speed: 11.9ms preprocess, 941.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 896.6ms
# Speed: 35.3ms preprocess, 896.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.4ms
# Speed: 13.9ms preprocess, 906.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.4ms
# Speed: 7.2ms preprocess, 923.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.5ms
# Speed: 14.6ms preprocess, 910.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.0ms
# Speed: 13.6ms preprocess, 918.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.2ms
# Speed: 15.3ms preprocess, 902.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 913.3ms
# Speed: 11.4ms preprocess, 913.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 932.0ms
# Speed: 15.3ms preprocess, 932.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 929.2ms
# Speed: 23.3ms preprocess, 929.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.3ms
# Speed: 13.1ms preprocess, 909.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.1ms
# Speed: 13.7ms preprocess, 916.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.3ms
# Speed: 14.1ms preprocess, 908.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.9ms
# Speed: 20.0ms preprocess, 915.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 937.5ms
# Speed: 18.4ms preprocess, 937.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.2ms
# Speed: 19.8ms preprocess, 905.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 895.8ms
# Speed: 19.3ms preprocess, 895.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 895.4ms
# Speed: 7.6ms preprocess, 895.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 935.1ms
# Speed: 7.2ms preprocess, 935.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 1010.2ms
# Speed: 17.4ms preprocess, 1010.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 931.3ms
# Speed: 21.9ms preprocess, 931.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 917.6ms
# Speed: 26.5ms preprocess, 917.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.8ms
# Speed: 16.6ms preprocess, 902.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.6ms
# Speed: 23.1ms preprocess, 911.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 931.6ms
# Speed: 20.7ms preprocess, 931.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.3ms
# Speed: 7.2ms preprocess, 890.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 897.1ms
# Speed: 5.7ms preprocess, 897.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 896.3ms
# Speed: 17.0ms preprocess, 896.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.2ms
# Speed: 7.2ms preprocess, 915.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 913.0ms
# Speed: 5.7ms preprocess, 913.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 900.4ms
# Speed: 14.8ms preprocess, 900.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.3ms
# Speed: 6.5ms preprocess, 912.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.0ms
# Speed: 11.9ms preprocess, 908.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.9ms
# Speed: 6.4ms preprocess, 912.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.5ms
# Speed: 36.1ms preprocess, 907.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.1ms
# Speed: 11.2ms preprocess, 914.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 927.9ms
# Speed: 13.4ms preprocess, 927.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 961.1ms
# Speed: 7.5ms preprocess, 961.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 925.5ms
# Speed: 12.9ms preprocess, 925.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.5ms
# Speed: 14.6ms preprocess, 923.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.3ms
# Speed: 7.3ms preprocess, 908.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.5ms
# Speed: 14.6ms preprocess, 910.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.5ms
# Speed: 6.5ms preprocess, 923.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.5ms
# Speed: 12.9ms preprocess, 912.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.2ms
# Speed: 9.2ms preprocess, 914.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.3ms
# Speed: 13.3ms preprocess, 920.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 917.2ms
# Speed: 14.9ms preprocess, 917.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 937.2ms
# Speed: 16.4ms preprocess, 937.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 948.9ms
# Speed: 10.1ms preprocess, 948.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 970.6ms
# Speed: 24.1ms preprocess, 970.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 924.2ms
# Speed: 28.8ms preprocess, 924.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.9ms
# Speed: 9.9ms preprocess, 909.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 922.9ms
# Speed: 8.3ms preprocess, 922.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.9ms
# Speed: 18.4ms preprocess, 901.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.0ms
# Speed: 13.2ms preprocess, 918.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.1ms
# Speed: 15.4ms preprocess, 926.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 930.8ms
# Speed: 23.6ms preprocess, 930.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.6ms
# Speed: 12.8ms preprocess, 909.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.5ms
# Speed: 12.8ms preprocess, 909.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.0ms
# Speed: 8.2ms preprocess, 919.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.6ms
# Speed: 13.7ms preprocess, 911.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 937.5ms
# Speed: 13.3ms preprocess, 937.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.9ms
# Speed: 10.6ms preprocess, 923.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.1ms
# Speed: 13.6ms preprocess, 926.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.5ms
# Speed: 13.1ms preprocess, 926.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 970.5ms
# Speed: 13.2ms preprocess, 970.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.9ms
# Speed: 12.2ms preprocess, 906.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.6ms
# Speed: 16.7ms preprocess, 906.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.4ms
# Speed: 7.3ms preprocess, 911.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.2ms
# Speed: 11.9ms preprocess, 919.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.0ms
# Speed: 13.4ms preprocess, 909.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.7ms
# Speed: 10.0ms preprocess, 916.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.3ms
# Speed: 9.3ms preprocess, 901.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.0ms
# Speed: 11.8ms preprocess, 901.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.6ms
# Speed: 17.6ms preprocess, 890.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 927.6ms
# Speed: 21.2ms preprocess, 927.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.8ms
# Speed: 14.2ms preprocess, 921.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.7ms
# Speed: 13.2ms preprocess, 904.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.8ms
# Speed: 9.9ms preprocess, 901.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 963.3ms
# Speed: 17.5ms preprocess, 963.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 957.3ms
# Speed: 11.9ms preprocess, 957.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.1ms
# Speed: 23.1ms preprocess, 923.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 925.7ms
# Speed: 12.2ms preprocess, 925.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 928.0ms
# Speed: 21.2ms preprocess, 928.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.5ms
# Speed: 28.7ms preprocess, 909.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.2ms
# Speed: 13.7ms preprocess, 918.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 937.7ms
# Speed: 7.6ms preprocess, 937.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.1ms
# Speed: 7.6ms preprocess, 904.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.3ms
# Speed: 17.0ms preprocess, 901.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.6ms
# Speed: 13.0ms preprocess, 919.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 930.0ms
# Speed: 8.1ms preprocess, 930.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.3ms
# Speed: 6.0ms preprocess, 919.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 924.9ms
# Speed: 13.0ms preprocess, 924.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 952.2ms
# Speed: 13.1ms preprocess, 952.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 925.7ms
# Speed: 23.8ms preprocess, 925.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.4ms
# Speed: 7.9ms preprocess, 918.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.4ms
# Speed: 22.0ms preprocess, 920.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 895.6ms
# Speed: 14.9ms preprocess, 895.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.2ms
# Speed: 7.1ms preprocess, 919.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.5ms
# Speed: 6.1ms preprocess, 921.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 877.6ms
# Speed: 14.1ms preprocess, 877.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.6ms
# Speed: 14.3ms preprocess, 906.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.2ms
# Speed: 29.7ms preprocess, 918.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.5ms
# Speed: 11.7ms preprocess, 905.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.4ms
# Speed: 13.0ms preprocess, 901.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.3ms
# Speed: 15.8ms preprocess, 904.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 900.8ms
# Speed: 11.9ms preprocess, 900.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.8ms
# Speed: 7.5ms preprocess, 914.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.9ms
# Speed: 19.0ms preprocess, 893.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 944.6ms
# Speed: 13.1ms preprocess, 944.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.8ms
# Speed: 23.6ms preprocess, 916.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 924.4ms
# Speed: 16.8ms preprocess, 924.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 894.4ms
# Speed: 31.7ms preprocess, 894.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 892.3ms
# Speed: 9.1ms preprocess, 892.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 892.1ms
# Speed: 8.4ms preprocess, 892.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.1ms
# Speed: 8.1ms preprocess, 920.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 898.9ms
# Speed: 18.9ms preprocess, 898.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 886.6ms
# Speed: 20.0ms preprocess, 886.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.5ms
# Speed: 7.7ms preprocess, 907.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.2ms
# Speed: 7.1ms preprocess, 914.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.7ms
# Speed: 13.9ms preprocess, 905.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 924.7ms
# Speed: 12.9ms preprocess, 924.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 897.5ms
# Speed: 26.4ms preprocess, 897.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.1ms
# Speed: 13.3ms preprocess, 890.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 882.4ms
# Speed: 24.5ms preprocess, 882.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 887.7ms
# Speed: 18.9ms preprocess, 887.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.5ms
# Speed: 26.3ms preprocess, 916.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.7ms
# Speed: 14.8ms preprocess, 890.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.4ms
# Speed: 6.8ms preprocess, 911.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 922.5ms
# Speed: 6.1ms preprocess, 922.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 917.1ms
# Speed: 14.8ms preprocess, 917.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.7ms
# Speed: 7.3ms preprocess, 919.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.0ms
# Speed: 8.1ms preprocess, 915.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.6ms
# Speed: 8.2ms preprocess, 920.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.8ms
# Speed: 11.7ms preprocess, 915.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.5ms
# Speed: 7.3ms preprocess, 910.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 903.2ms
# Speed: 14.6ms preprocess, 903.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.7ms
# Speed: 7.7ms preprocess, 905.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.3ms
# Speed: 8.1ms preprocess, 921.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 1036.1ms
# Speed: 9.3ms preprocess, 1036.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.6ms
# Speed: 13.8ms preprocess, 938.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 888.2ms
# Speed: 30.0ms preprocess, 888.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 883.8ms
# Speed: 12.9ms preprocess, 883.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 895.1ms
# Speed: 12.6ms preprocess, 895.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.7ms
# Speed: 17.8ms preprocess, 926.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 883.7ms
# Speed: 13.2ms preprocess, 883.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.2ms
# Speed: 22.6ms preprocess, 910.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 885.4ms
# Speed: 23.6ms preprocess, 885.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 903.8ms
# Speed: 23.4ms preprocess, 903.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 930.7ms
# Speed: 11.2ms preprocess, 930.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.9ms
# Speed: 16.8ms preprocess, 906.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.0ms
# Speed: 11.9ms preprocess, 907.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.8ms
# Speed: 11.6ms preprocess, 910.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.0ms
# Speed: 6.8ms preprocess, 911.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.5ms
# Speed: 13.3ms preprocess, 906.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.2ms
# Speed: 17.7ms preprocess, 912.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 941.2ms
# Speed: 10.3ms preprocess, 941.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.5ms
# Speed: 15.0ms preprocess, 938.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 949.3ms
# Speed: 18.5ms preprocess, 949.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 913.2ms
# Speed: 14.7ms preprocess, 913.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 924.1ms
# Speed: 7.7ms preprocess, 924.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.8ms
# Speed: 7.9ms preprocess, 919.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.0ms
# Speed: 8.2ms preprocess, 909.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 899.2ms
# Speed: 13.7ms preprocess, 899.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 897.5ms
# Speed: 13.3ms preprocess, 897.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.0ms
# Speed: 8.1ms preprocess, 915.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.7ms
# Speed: 7.8ms preprocess, 918.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 928.7ms
# Speed: 13.3ms preprocess, 928.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.8ms
# Speed: 13.2ms preprocess, 910.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 985.5ms
# Speed: 7.6ms preprocess, 985.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 954.0ms
# Speed: 25.7ms preprocess, 954.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 937.8ms
# Speed: 18.9ms preprocess, 937.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 954.4ms
# Speed: 11.4ms preprocess, 954.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.1ms
# Speed: 13.2ms preprocess, 916.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 941.6ms
# Speed: 23.6ms preprocess, 941.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 931.5ms
# Speed: 26.4ms preprocess, 931.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.6ms
# Speed: 17.1ms preprocess, 938.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 898.3ms
# Speed: 11.8ms preprocess, 898.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.3ms
# Speed: 8.9ms preprocess, 902.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 889.8ms
# Speed: 6.0ms preprocess, 889.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 943.1ms
# Speed: 12.0ms preprocess, 943.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.2ms
# Speed: 18.1ms preprocess, 916.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.5ms
# Speed: 8.2ms preprocess, 919.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.9ms
# Speed: 26.8ms preprocess, 909.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.1ms
# Speed: 12.1ms preprocess, 938.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 940.7ms
# ...
# Speed: 30.3ms preprocess, 952.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 958.5ms
# Speed: 11.7ms preprocess, 958.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.5ms
# Speed: 8.4ms preprocess, 938.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 934.4ms
# Speed: 15.4ms preprocess, 934.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.7ms
# Speed: 25.7ms preprocess, 893.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 896.7ms
# Speed: 9.4ms preprocess, 896.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.2ms
# Speed: 8.6ms preprocess, 923.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 934.2ms
# Speed: 17.7ms preprocess, 934.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 946.8ms
# Speed: 9.5ms preprocess, 946.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.2ms
# Speed: 6.5ms preprocess, 907.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 932.4ms
# Speed: 7.0ms preprocess, 932.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 903.8ms
# Speed: 7.5ms preprocess, 903.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 896.5ms
# Speed: 14.8ms preprocess, 896.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 935.7ms
# Speed: 6.4ms preprocess, 935.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.0ms
# Speed: 12.7ms preprocess, 923.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 899.7ms
# Speed: 17.7ms preprocess, 899.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 885.7ms
# Speed: 45.6ms preprocess, 885.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.5ms
# Speed: 6.7ms preprocess, 919.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.2ms
# Speed: 23.0ms preprocess, 907.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.4ms
# Speed: 8.9ms preprocess, 908.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.3ms
# Speed: 13.5ms preprocess, 905.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 917.5ms
# Speed: 19.2ms preprocess, 917.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 913.1ms
# Speed: 9.8ms preprocess, 913.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.2ms
# Speed: 8.3ms preprocess, 893.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.2ms
# Speed: 12.3ms preprocess, 901.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 896.4ms
# Speed: 5.3ms preprocess, 896.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 957.2ms
# Speed: 15.4ms preprocess, 957.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.5ms
# Speed: 13.9ms preprocess, 902.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.3ms
# Speed: 12.0ms preprocess, 902.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.1ms
# Speed: 5.9ms preprocess, 920.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.8ms
# Speed: 16.2ms preprocess, 907.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.0ms
# Speed: 22.9ms preprocess, 908.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 884.9ms
# Speed: 10.7ms preprocess, 884.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.9ms
# Speed: 20.9ms preprocess, 926.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.1ms
# Speed: 11.1ms preprocess, 911.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 919.2ms
# Speed: 9.8ms preprocess, 919.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 897.3ms
# Speed: 11.0ms preprocess, 897.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.7ms
# Speed: 6.3ms preprocess, 911.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.1ms
# Speed: 17.2ms preprocess, 915.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.4ms
# Speed: 6.8ms preprocess, 914.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.2ms
# Speed: 10.9ms preprocess, 908.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.6ms
# Speed: 21.7ms preprocess, 905.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.1ms
# Speed: 18.5ms preprocess, 911.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 957.7ms
# Speed: 13.9ms preprocess, 957.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 1030.4ms
# Speed: 21.4ms preprocess, 1030.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 938.2ms
# Speed: 13.0ms preprocess, 938.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 931.4ms
# Speed: 18.6ms preprocess, 931.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 929.1ms
# Speed: 20.2ms preprocess, 929.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.9ms
# Speed: 7.6ms preprocess, 920.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 932.1ms
# Speed: 8.7ms preprocess, 932.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.7ms
# Speed: 6.5ms preprocess, 914.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.2ms
# Speed: 14.1ms preprocess, 921.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.2ms
# Speed: 6.3ms preprocess, 921.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 932.4ms
# Speed: 17.7ms preprocess, 932.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.4ms
# Speed: 16.9ms preprocess, 902.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.6ms
# Speed: 13.1ms preprocess, 907.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 918.5ms
# Speed: 7.9ms preprocess, 918.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.0ms
# Speed: 5.9ms preprocess, 915.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 916.6ms
# Speed: 6.1ms preprocess, 916.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 902.3ms
# Speed: 17.4ms preprocess, 902.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 906.8ms
# Speed: 15.0ms preprocess, 906.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.4ms
# Speed: 8.9ms preprocess, 910.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 947.5ms
# Speed: 16.9ms preprocess, 947.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.4ms
# Speed: 9.4ms preprocess, 890.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.7ms
# Speed: 10.5ms preprocess, 908.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 898.9ms
# Speed: 17.6ms preprocess, 898.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 921.0ms
# Speed: 20.7ms preprocess, 921.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.4ms
# Speed: 28.6ms preprocess, 910.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.4ms
# Speed: 24.4ms preprocess, 893.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 907.7ms
# Speed: 8.4ms preprocess, 907.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.1ms
# Speed: 18.1ms preprocess, 910.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 942.4ms
# Speed: 16.8ms preprocess, 942.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 979.5ms
# Speed: 23.2ms preprocess, 979.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 936.3ms
# Speed: 26.3ms preprocess, 936.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 909.5ms
# Speed: 17.8ms preprocess, 909.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.6ms
# Speed: 6.8ms preprocess, 901.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.7ms
# Speed: 29.8ms preprocess, 912.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 908.7ms
# Speed: 11.4ms preprocess, 908.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 922.3ms
# Speed: 23.1ms preprocess, 922.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 912.8ms
# Speed: 13.5ms preprocess, 912.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.4ms
# Speed: 6.9ms preprocess, 901.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.2ms
# Speed: 20.8ms preprocess, 905.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 925.7ms
# Speed: 8.7ms preprocess, 925.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 922.7ms
# Speed: 7.5ms preprocess, 922.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.9ms
# Speed: 7.8ms preprocess, 910.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 915.2ms
# Speed: 7.3ms preprocess, 915.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.7ms
# Speed: 7.1ms preprocess, 911.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.5ms
# Speed: 9.7ms preprocess, 910.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.7ms
# Speed: 7.2ms preprocess, 905.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 922.6ms
# Speed: 7.7ms preprocess, 922.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.6ms
# Speed: 11.2ms preprocess, 901.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 911.7ms
# Speed: 7.8ms preprocess, 911.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 910.2ms
# Speed: 8.7ms preprocess, 910.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 890.4ms
# Speed: 13.0ms preprocess, 890.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.6ms
# Speed: 7.5ms preprocess, 904.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 900.0ms
# Speed: 6.9ms preprocess, 900.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 895.1ms
# Speed: 13.2ms preprocess, 895.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.8ms
# Speed: 13.0ms preprocess, 905.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 929.7ms
# Speed: 8.6ms preprocess, 929.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.8ms
# Speed: 11.5ms preprocess, 893.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.9ms
# Speed: 16.4ms preprocess, 904.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 961.8ms
# Speed: 20.4ms preprocess, 961.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 944.0ms
# Speed: 5.7ms preprocess, 944.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 961.3ms
# Speed: 5.7ms preprocess, 961.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 893.5ms
# Speed: 17.7ms preprocess, 893.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 923.7ms
# Speed: 5.3ms preprocess, 923.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 900.6ms
# Speed: 20.5ms preprocess, 900.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 948.7ms
# Speed: 20.0ms preprocess, 948.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 928.2ms
# Speed: 11.8ms preprocess, 928.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 913.6ms
# Speed: 17.6ms preprocess, 913.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 905.8ms
# Speed: 8.0ms preprocess, 905.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.2ms
# Speed: 7.4ms preprocess, 901.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 935.0ms
# Speed: 26.6ms preprocess, 935.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.4ms
# Speed: 14.4ms preprocess, 914.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 926.0ms
# Speed: 7.9ms preprocess, 926.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 942.0ms
# Speed: 7.3ms preprocess, 942.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 897.6ms
# Speed: 29.8ms preprocess, 897.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 884.7ms
# Speed: 24.5ms preprocess, 884.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 914.3ms
# Speed: 6.8ms preprocess, 914.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 904.7ms
# Speed: 6.8ms preprocess, 904.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 920.5ms
# Speed: 18.0ms preprocess, 920.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 903.8ms
# Speed: 6.9ms preprocess, 903.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 2 sheeps, 901.7ms
# Speed: 11.5ms preprocess, 901.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
# End of video or unable to read frame.
# Processing complete.
# Processed video saved at: /kaggle/working/processed_sheep_video.mp4
# Movement graph saved at: /kaggle/working/sheep_movement_graph.png

# %%
import firebase_admin
from firebase_admin import credentials, db
import datetime

# Firebase app name
app_name = 'sheep_monitoring_app'

# Initialize Firebase if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials/credentials.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)

# Access the initialized app
app = firebase_admin.get_app(name=app_name)

# Function to update sheep data in Firebase
def update_sheep_data(sheep_id, coordinates, health_status, activity):
    # Create a reference to the Firebase database
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)

    # Format data to be sent to Firebase
    data = {
        "coordinates": coordinates,
        "healthStatus": health_status,
        "activity": activity,
        "timestamp": datetime.datetime.utcnow().isoformat()  # Add a timestamp
    }

    # Update the sheep data in Firebase
    sheep_ref.set(data)
    print(f"Updated data for {sheep_id} in Firebase.")

# Example model data
model_sheep_data = {
    "sheepID1": {
        "coordinates": "34.0522,-118.2437",  # Example coordinates (latitude, longitude)
        "health_status": "healthy",
        "activity": "grazing"
    },
    "sheepID2": {
        "coordinates": "40.7128,-74.0060",
        "health_status": "injured",
        "activity": "resting"
    }
}

# Send data to Firebase for each sheep
for sheep_id, data in model_sheep_data.items():
    update_sheep_data(sheep_id, data["coordinates"], data["health_status"], data["activity"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import firebase_admin
#       2 from firebase_admin import credentials, db
#       3 import datetime
#
# ModuleNotFoundError: No module named 'firebase_admin'

# %%
# !pip install python-firebase

# %%
# !pip install firebase-admin

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2
import firebase_admin
from firebase_admin import credentials, db
import datetime

# Firebase app name
app_name = 'sheep_monitoring_app'

# Initialize Firebase if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials-file/credentials.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)

# Access the initialized app
app = firebase_admin.get_app(name=app_name)

# Function to update sheep data in Firebase
def update_sheep_data(sheep_id, coordinates, speed, status):
    # Create a reference to the Firebase database
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)

    # Format data to be sent to Firebase
    data = {
        "coordinates": coordinates,
        "speed": speed,
        "status": status,
        "timestamp": datetime.datetime.utcnow().isoformat()  # Add a timestamp
    }

    # Update the sheep data in Firebase
    sheep_ref.set(data)
    print(f"Updated data for {sheep_id} in Firebase.")

# Initialize YOLO model
model_path = '/kaggle/input/detection-model-best/best.pt'  # Replace with your model path
model = YOLO(model_path)

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video path
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'  # Replace with your video path
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video settings
output_video_path = '/kaggle/working/processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Movement data structures
sheep_tracks = defaultdict(list)
prev_positions = {}  # Store previous positions for speed calculation
abnormal_ids = set()  # Track IDs with abnormal speed

# Speed thresholds (pixels/frame)
NORMAL_SPEED_MIN = 10.0
NORMAL_SPEED_MAX = 50.0

# Process video frames
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or unable to read frame.")
        break

    # Detect sheep using YOLO
    results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
    detections = []
    for result in results:
        for box in result.boxes:
            try:
                x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                if confidence > 0.5 and class_id == 0:  # Sheep class
                    detections.append([[x1, y1, x2, y2], confidence])
            except Exception as e:
                print(f"Error processing box: {e}")
                continue

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        x, y, w, h = track.to_ltwh()
        center_x = int(x + w / 2)
        center_y = int(y + h / 2)

        # Track movement
        sheep_tracks[track_id].append((center_x, center_y))

        # Calculate speed
        speed = 0
        if track_id in prev_positions:
            prev_x, prev_y = prev_positions[track_id]
            speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

            # Flag abnormal speeds
            if speed < NORMAL_SPEED_MIN or speed > NORMAL_SPEED_MAX:
                abnormal_ids.add(track_id)
                cv2.putText(frame, f"ID {track_id} (Abnormal Speed)", (int(x), int(y) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
        prev_positions[track_id] = (center_x, center_y)

        # Update Firebase
        status = "abnormal" if track_id in abnormal_ids else "normal"
        update_sheep_data(track_id, f"{center_x},{center_y}", speed, status)

        # Draw bounding box and ID
        color = (0, 0, 255) if track_id in abnormal_ids else (0, 255, 0)
        cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
        cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Write frame to output video
    out.write(frame)
    frame_count += 1

# Release resources
cap.release()
out.release()

# Plot sheep movement
plt.figure(figsize=(12, 8))
for track_id, path in sheep_tracks.items():
    x_coords = [p[0] for p in path]
    y_coords = [p[1] for p in path]
    linestyle = '--' if track_id in abnormal_ids else '-'
    color = 'red' if track_id in abnormal_ids else 'green'
    plt.plot(x_coords, y_coords, linestyle=linestyle, color=color, label=f"ID {track_id}")

plt.xlabel("X-Coordinate (pixels)")
plt.ylabel("Y-Coordinate (pixels)")
plt.title("Sheep Movement Paths")
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis()  # Invert Y-axis for video frame coordinates

# Save movement graph
graph_path = '/kaggle/working/sheep_movement_graph.png'
plt.savefig(graph_path)
plt.close()

print("Processing complete.")
print(f"Processed video saved at: {output_video_path}")
print(f"Movement graph saved at: {graph_path}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2
import firebase_admin
from firebase_admin import credentials, db
import datetime

# Firebase app name
app_name = 'sheep_monitoring_app'

# Initialize Firebase if not already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials-file/credentials.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)

# Access the initialized app
app = firebase_admin.get_app(name=app_name)

# Function to update sheep data in Firebase
def update_sheep_data(sheep_id, coordinates, speed, status):
    # Create a reference to the Firebase database
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)

    # Format data to be sent to Firebase
    data = {
        "coordinates": coordinates,
        "speed": speed,
        "status": status,
        "timestamp": datetime.datetime.utcnow().isoformat()  # Add a timestamp
    }

    # Update the sheep data in Firebase
    sheep_ref.set(data)
    print(f"Updated data for {sheep_id} in Firebase.")

# Initialize YOLO model
model_path = '/kaggle/input/detection-model-best/best.pt'  # Replace with your model path
model = YOLO(model_path)

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video path
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'  # Replace with your video path
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video settings
output_video_path = '/kaggle/working/processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Movement data structures
sheep_tracks = defaultdict(list)
prev_positions = {}  # Store previous positions for speed calculation
abnormal_ids = set()  # Track IDs with abnormal speed

# Speed thresholds (pixels/frame)
NORMAL_SPEED_MIN = 100.0
NORMAL_SPEED_MAX = 200.0

# Process video frames
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video or unable to read frame.")
        break

    # Detect sheep using YOLO
    results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
    detections = []
    for result in results:
        for box in result.boxes:
            try:
                x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                confidence = float(box.conf[0])
                class_id = int(box.cls[0])
                if confidence > 0.5 and class_id == 0:  # Sheep class
                    detections.append([[x1, y1, x2, y2], confidence])
            except Exception as e:
                print(f"Error processing box: {e}")
                continue

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        x, y, w, h = track.to_ltwh()
        center_x = int(x + w / 2)
        center_y = int(y + h / 2)

        # Track movement
        sheep_tracks[track_id].append((center_x, center_y))

        # Calculate speed
        speed = 0
        if track_id in prev_positions:
            prev_x, prev_y = prev_positions[track_id]
            speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

            # Flag abnormal speeds
            if speed < NORMAL_SPEED_MIN or speed > NORMAL_SPEED_MAX:
                abnormal_ids.add(track_id)
                cv2.putText(frame, f"ID {track_id} (Abnormal Speed)", (int(x), int(y) - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
        prev_positions[track_id] = (center_x, center_y)

        # Update Firebase
        status = "abnormal" if track_id in abnormal_ids else "normal"
        update_sheep_data(track_id, f"{center_x},{center_y}", speed, status)

        # Draw bounding box and ID
        color = (0, 0, 255) if track_id in abnormal_ids else (0, 255, 0)
        cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
        cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Write frame to output video
    out.write(frame)
    frame_count += 1

# Release resources
cap.release()
out.release()

# Plot sheep movement
plt.figure(figsize=(12, 8))
for track_id, path in sheep_tracks.items():
    x_coords = [p[0] for p in path]
    y_coords = [p[1] for p in path]
    linestyle = '--' if track_id in abnormal_ids else '-'
    color = 'red' if track_id in abnormal_ids else 'green'
    plt.plot(x_coords, y_coords, linestyle=linestyle, color=color, label=f"ID {track_id}")

plt.xlabel("X-Coordinate (pixels)")
plt.ylabel("Y-Coordinate (pixels)")
plt.title("Sheep Movement Paths")
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis()  # Invert Y-axis for video frame coordinates

# Save movement graph
graph_path = '/kaggle/working/sheep_movement_graph.png'
plt.savefig(graph_path)
plt.close()

print(f"Movement graph saved at: {graph_path}")

# Calculate and plot sheep distance vs. time
plt.figure(figsize=(12, 8))

for track_id, path in sheep_tracks.items():
    distances = [0]  # Initialize with 0 distance at the starting point
    timestamps = list(range(len(path)))  # Use frame count as a proxy for time

    # Calculate cumulative distance over time
    for i in range(1, len(path)):
        x1, y1 = path[i - 1]
        x2, y2 = path[i]
        distance = np.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)
        distances.append(distances[-1] + distance)  # Cumulative sum of distances

    # Plot the distance vs. time for the current track
    linestyle = '--' if track_id in abnormal_ids else '-'
    color = 'red' if track_id in abnormal_ids else 'green'
    plt.plot(timestamps, distances, linestyle=linestyle, color=color, label=f"ID {track_id}")

plt.xlabel("Time (frames)")
plt.ylabel("Cumulative Distance (pixels)")
plt.title("Sheep Distance vs. Time")
plt.legend()
plt.grid(True)

# Save distance vs. time graph
distance_graph_path = '/kaggle/working/sheep_distance_vs_time_graph.png'
plt.savefig(distance_graph_path)
plt.close()

print(f"Distance vs. Time graph saved at: {distance_graph_path}")
print(f"Processed video saved at: {output_video_path}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2
import firebase_admin
from firebase_admin import credentials, db
import datetime
import csv
import os

# Firebase setup
app_name = 'sheep_monitoring_app'
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials-file/credentials.json")  # Ensure the credentials file is in the same directory
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)
app = firebase_admin.get_app(name=app_name)

# Function to update sheep data in Firebase
def update_sheep_data(sheep_id, coordinates, speed, health_status):
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)
    data = {
        "coordinates": coordinates,
        "speed": speed,
        "health_status": health_status,
        "timestamp": datetime.datetime.utcnow().isoformat()
    }
    sheep_ref.set(data)

# Initialize YOLO and DeepSORT
model_path = '/kaggle/input/detection-model-best/best.pt'  # Place the model file in the same directory
model = YOLO(model_path)
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video settings
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'  # Replace with your video file path
cap = cv2.VideoCapture(video_path)

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
output_video_path = 'processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# CSV file setup
csv_path = 'tracking_results.csv'
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Sheep ID', 'X Coordinate', 'Y Coordinate', 'Speed', 'Health Status', 'Timestamp'])

    # Tracking setup
    sheep_tracks = defaultdict(list)
    prev_positions = {}
    abnormal_ids = set()
    NORMAL_SPEED_MIN = 0
    NORMAL_SPEED_MAX = 1.5

    # Process video
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("End of video.")
            break

        # Detect sheep
        results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
        detections = []
        for result in results:
            for box in result.boxes:
                try:
                    x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                    confidence = float(box.conf[0])
                    class_id = int(box.cls[0])
                    if confidence > 0.5 and class_id == 0:  # Sheep class
                        detections.append([[x1, y1, x2, y2], confidence])
                except Exception as e:
                    print(f"Error processing box: {e}")
                    continue

        # Update tracker
        tracks = tracker.update_tracks(detections, frame=frame)
        for track in tracks:
            if not track.is_confirmed():
                continue

            track_id = track.track_id
            x, y, w, h = track.to_ltwh()
            center_x = int(x + w / 2)
            center_y = int(y + h / 2)

            # Calculate speed
            speed = 0
            if track_id in prev_positions:
                prev_x, prev_y = prev_positions[track_id]
                speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

                # Check for abnormal speeds
                if speed < NORMAL_SPEED_MIN or speed > NORMAL_SPEED_MAX:
                    abnormal_ids.add(track_id)

            prev_positions[track_id] = (center_x, center_y)
            health_status = "abnormal" if track_id in abnormal_ids else "normal"

            # Write to CSV
            writer.writerow([track_id, center_x, center_y, speed, health_status, datetime.datetime.utcnow().isoformat()])

            # Update Firebase
            update_sheep_data(track_id, f"{center_x},{center_y}", speed, health_status)

            # Draw bounding box
            color = (0, 0, 255) if track_id in abnormal_ids else (0, 255, 0)
            cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
            cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        out.write(frame)

# Release resources
cap.release()
out.release()
print(f"Processed video saved at: {output_video_path}")
print(f"Tracking data saved at: {csv_path}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2
import firebase_admin
from firebase_admin import credentials, db
import datetime
import csv
import os
from scipy.spatial import ConvexHull

# Firebase setup
app_name = 'sheep_monitoring_app'
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials-file/credentials.json")  # Ensure the credentials file is in the same directory
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)
app = firebase_admin.get_app(name=app_name)

# Function to update sheep data in Firebase
def update_sheep_data(sheep_id, coordinates, speed, health_status, avg_distance, area, stop_count, distance_from_group):
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)
    data = {
        "coordinates": coordinates,
        "speed": speed,
        "health_status": health_status,
        "avg_distance": avg_distance,
        "area": area,
        "stop_count": stop_count,
        "distance_from_group": distance_from_group,
        "timestamp": datetime.datetime.utcnow().isoformat()
    }
    sheep_ref.set(data)

# Initialize YOLO and DeepSORT
model_path = '/kaggle/input/detection-model-best/best.pt'  # Place the model file in the same directory
model = YOLO(model_path)
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video settings
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'  # Replace with your video file path
cap = cv2.VideoCapture(video_path)

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
output_video_path = 'processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# CSV file setup
csv_path = 'tracking_results.csv'
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Sheep ID', 'X Coordinate', 'Y Coordinate', 'Speed', 'Health Status', 'Timestamp'])

    # Tracking setup
    sheep_tracks = defaultdict(list)
    prev_positions = {}
    abnormal_ids = set()
    NORMAL_SPEED_MIN = 0  # Grazing sheep can stay stationary
    NORMAL_SPEED_MAX = 1.5  # Maximum grazing speed
    grazing_time = defaultdict(int)  # To track grazing-like behavior duration

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("End of video.")
            break

        # Detect sheep
        results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
        detections = []
        for result in results:
            for box in result.boxes:
                try:
                    x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                    confidence = float(box.conf[0])
                    class_id = int(box.cls[0])
                    if confidence > 0.5 and class_id == 0:  # Sheep class
                        detections.append([[x1, y1, x2, y2], confidence])
                except Exception as e:
                    print(f"Error processing box: {e}")
                    continue

        # Update tracker
        tracks = tracker.update_tracks(detections, frame=frame)
        group_centroids = []  # For calculating group behavior
        for track in tracks:
            if not track.is_confirmed():
                continue

            track_id = track.track_id
            x, y, w, h = track.to_ltwh()
            center_x = int(x + w / 2)
            center_y = int(y + h / 2)

            # Track movement
            sheep_tracks[track_id].append((center_x, center_y))
            group_centroids.append((center_x, center_y))

            # Calculate speed
            speed = 0
            if track_id in prev_positions:
                prev_x, prev_y = prev_positions[track_id]
                speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

            prev_positions[track_id] = (center_x, center_y)

            # Check movement patterns over time
            trajectory = sheep_tracks[track_id]
            distances = []
            if len(trajectory) > 10:  # Use the last 10 movements
                distances = [
                    np.sqrt((trajectory[i][0] - trajectory[i - 1][0]) ** 2 +
                            (trajectory[i][1] - trajectory[i - 1][1]) ** 2)
                    for i in range(1, len(trajectory))
                ]
                avg_distance = sum(distances) / len(distances)
            else:
                avg_distance = 0

            # Check area covered by movement
            if len(trajectory) > 3:
                points = np.array(trajectory)
                hull = ConvexHull(points)
                area = hull.volume  # Approximate area covered
            else:
                area = 0

            # Check frequency of stops
            stop_count = sum(1 for d in distances if d < 0.5) if len(trajectory) > 1 else 0

            # Group behavior: calculate deviation from group centroid
            if group_centroids:
                group_centroid_x = np.mean([pos[0] for pos in group_centroids])
                group_centroid_y = np.mean([pos[1] for pos in group_centroids])
                distance_from_group = np.sqrt((center_x - group_centroid_x) ** 2 + (center_y - group_centroid_y) ** 2)
            else:
                distance_from_group = 0

            # Combine multiple indicators
            grazing_score = 0
            if avg_distance < 2:  # Small average movement
                grazing_score += 1
            if area < 100:  # Small area indicates grazing
                grazing_score += 1
            if stop_count > 5:  # Frequent stops indicate grazing
                grazing_score += 1
            if distance_from_group < 50:  # Grazing sheep stay near the group
                grazing_score += 1

            # Determine health status
            health_status = "normal" if grazing_score >= 3 else "abnormal"

            # Write to CSV
            writer.writerow([track_id, center_x, center_y, speed, health_status, datetime.datetime.utcnow().isoformat()])

            # Update Firebase
            update_sheep_data(track_id, f"{center_x},{center_y}", speed, health_status, avg_distance, area, stop_count, distance_from_group)

            # Draw bounding box
            color = (0, 0, 255) if health_status == "abnormal" else (0, 255, 0)
            cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
            cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        out.write(frame)

# Release resources
cap.release()
out.release()
print(f"Processed video saved at: {output_video_path}")
print(f"Tracking data saved at: {csv_path}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, deque
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2
import firebase_admin
from firebase_admin import credentials, db
import datetime
import csv
import os
from scipy.spatial import ConvexHull
from sklearn.cluster import DBSCAN

# Firebase setup
app_name = 'sheep_monitoring_app'
if not firebase_admin._apps:
    cred = credentials.Certificate("/kaggle/input/firebase-credentials-file/credentials.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://sheep-monitoring-7dc33-default-rtdb.firebaseio.com'
    }, name=app_name)
app = firebase_admin.get_app(name=app_name)

def update_sheep_data(sheep_id, coordinates, speed, health_status, avg_distance, area, stop_count, distance_from_group):
    sheep_ref = db.reference(f'sheep/{sheep_id}', app=app)
    data = {
        "coordinates": coordinates,
        "speed": speed,
        "health_status": health_status,
        "avg_distance": avg_distance,
        "area": area,
        "stop_count": stop_count,
        "distance_from_group": distance_from_group,
        "timestamp": datetime.datetime.utcnow().isoformat()
    }
    sheep_ref.set(data)

# Initialize YOLO and DeepSORT
model_path = '/kaggle/input/detection-model-best/best.pt'
model = YOLO(model_path)
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Video settings
video_path = '/kaggle/input/sheep-video/Sheepeating.mp4'
cap = cv2.VideoCapture(video_path)

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
output_video_path = 'processed_sheep_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# CSV file setup
csv_path = 'tracking_results.csv'
with open(csv_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Sheep ID', 'X Coordinate', 'Y Coordinate', 'Speed', 'Health Status', 'Timestamp'])

    sheep_tracks = defaultdict(list)
    prev_positions = {}
    speed_history = defaultdict(lambda: deque(maxlen=30))
    grazing_history = defaultdict(lambda: deque(maxlen=30))
    group_deviation_history = defaultdict(lambda: deque(maxlen=30))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("End of video.")
            break

        # Detect sheep
        results = model.predict(frame, stream=True, conf=0.5, iou=0.45)
        detections = []
        for result in results:
            for box in result.boxes:
                try:
                    x1, y1, x2, y2 = int(box.xyxy[0][0]), int(box.xyxy[0][1]), int(box.xyxy[0][2]), int(box.xyxy[0][3])
                    confidence = float(box.conf[0])
                    class_id = int(box.cls[0])
                    if confidence > 0.5 and class_id == 0:
                        detections.append([[x1, y1, x2, y2], confidence])
                except Exception as e:
                    print(f"Error processing box: {e}")
                    continue

        # Update tracker
        tracks = tracker.update_tracks(detections, frame=frame)
        group_centroids = []  # For calculating group behavior
        all_positions = []

        for track in tracks:
            if not track.is_confirmed():
                continue

            track_id = track.track_id
            x, y, w, h = track.to_ltwh()
            center_x = int(x + w / 2)
            center_y = int(y + h / 2)

            sheep_tracks[track_id].append((center_x, center_y))
            group_centroids.append((center_x, center_y))
            all_positions.append([center_x, center_y])

            # Calculate speed
            speed = 0
            if track_id in prev_positions:
                prev_x, prev_y = prev_positions[track_id]
                speed = np.sqrt((center_x - prev_x) ** 2 + (center_y - prev_y) ** 2)

            prev_positions[track_id] = (center_x, center_y)

            # Check historical trends
            speed_history[track_id].append(speed)
            avg_speed = np.mean(speed_history[track_id])

            trajectory = sheep_tracks[track_id]
            distances = [
                np.sqrt((trajectory[i][0] - trajectory[i - 1][0]) ** 2 +
                        (trajectory[i][1] - trajectory[i - 1][1]) ** 2)
                for i in range(1, len(trajectory))
            ] if len(trajectory) > 1 else []

            avg_distance = sum(distances) / len(distances) if distances else 0
            area = ConvexHull(np.array(trajectory)).volume if len(trajectory) > 3 else 0
            stop_count = sum(1 for d in distances if d < 0.5)

            # Clustering using DBSCAN
            if len(all_positions) > 1:
                clustering = DBSCAN(eps=50, min_samples=2).fit(all_positions)
                cluster_label = clustering.labels_[group_centroids.index((center_x, center_y))]
                distance_from_group = 0 if cluster_label == -1 else np.linalg.norm(np.array([center_x, center_y]) - np.mean(np.array(all_positions), axis=0))
            else:
                distance_from_group = 0

            group_deviation_history[track_id].append(distance_from_group)
            avg_group_deviation = np.mean(group_deviation_history[track_id])

            grazing_score = 0
            if avg_distance < 2: grazing_score += 1
            if area < 100: grazing_score += 1
            if stop_count > 5: grazing_score += 1
            if distance_from_group < 50: grazing_score += 1
            grazing_history[track_id].append(grazing_score)

            # Determine health status
            health_status = "normal" if grazing_score >= 3 else "abnormal"

            # Write to CSV
            writer.writerow([track_id, center_x, center_y, speed, health_status, datetime.datetime.utcnow().isoformat()])

            # Update Firebase
            update_sheep_data(track_id, f"{center_x},{center_y}", speed, health_status, avg_distance, area, stop_count, distance_from_group)

            # Visualization
            color = (0, 0, 255) if health_status == "abnormal" else (0, 255, 0)
            cv2.rectangle(frame, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
            cv2.putText(frame, f"ID {track_id}", (int(x), int(y) - 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            cv2.putText(frame, f"Health: {health_status}", (int(x), int(y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            cv2.putText(frame, f"Grazing: {grazing_score}", (int(x), int(y) + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Add legend
        cv2.rectangle(frame, (10, 10), (300, 100), (255, 255, 255), -1)
        cv2.putText(frame, "Legend:", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)
        cv2.putText(frame, "Green: Normal", (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        cv2.putText(frame, "Red: Abnormal", (20, 70), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        out.write(frame)

cap.release()
out.release()
print(f"Processed video saved at: {output_video_path}")
print(f"Tracking data saved at: {csv_path}")

# %%
# !pip install torch

# %%
import torch

# Save the DeepSORT tracker state
tracker_state_path = 'deep_sort_tracker_state.pth'
torch.save(tracker.state_dict(), tracker_state_path)

# %%
# Save the DeepSORT tracker state
tracker_state_path = 'deep_sort_tracker_state.pth'
torch.save(tracker.state_dict(), tracker_state_path)
